# %%
import Bauteil,AOI,BCF,Control
import q_main
import ifcopenshell
from ifcopenshell.util.selector import Selector
from ifcopenshell.util import element
import json
selector = Selector()
settings = ifcopenshell.geom.settings()
settings.set(settings.USE_PYTHON_OPENCASCADE, True) 


### Enter data file name (.ttl) ###

data_filename = 'st_2079.ttl'

### Enter model file name (.ifc) ###

filename = "st_2079.ifc"

### Enter model file name converted to LBD-Format (.ttl) ###

lbd_filename = 'st_2079_lbd.ttl'

### The next files will be created 

bt_filename = "control.ifc"
aoi_filename = "damage.ifc"



### Building component location begins here:

Control.create_bt_file(filename,bt_filename)
model = ifcopenshell.open(filename)
f = ifcopenshell.open(bt_filename)

bauteildefinition_list = q_main.get_bauteildefinition(data_filename)

with open("map_bauteilTyp.json", "r") as file:
    map_bT = json.loads(file.read())

h  = 0

for bauteildefinition in bauteildefinition_list:

    try:

        print("_____________________________________________________")
        print(bauteildefinition)

        dictionary_oa = q_main.get_Ortsangabe(data_filename,bauteildefinition)[0]
        dictionary_tesBauteil = q_main.get_Ortsangabe(data_filename,bauteildefinition)[1]
        dictionary_feld = q_main.get_Ortsangabe(data_filename,bauteildefinition)[2]
        dictionary_links_rechts = q_main.get_Ortsangabe(data_filename,bauteildefinition)[3]
        dictionary_anfang_ende = q_main.get_Ortsangabe(data_filename,bauteildefinition)[4]
        ifcBridgeName_list = q_main.get_ifcBridgeName(data_filename,bauteildefinition)
        bT = []

        for j in ifcBridgeName_list:
            res = map_bT[j]
            if "ignore" not in res and res not in bT:
                bT.append(map_bT[j])
        
        if len(bT)>0:
            ifcBridgeName = bT[0]
        else:
            ifcBridgeName = "No ifcBridgeName found"
        

        print("Nicht klassifizierte Ortsangaben: ", end = '')
        print(dictionary_oa)
        print("Ortsangaben Anfang/Ende: ", end = '')
        print(dictionary_anfang_ende)
        print("Ortsangaben für Bauteilsuche: ", end = '')
        print(dictionary_tesBauteil)
        print("Feld :", end = '')
        print(dictionary_feld)
        print("Links/Rechts:", end = '')
        print(dictionary_links_rechts)
        print("ifcBridgeName: ")
        print(ifcBridgeName)
        if len(dictionary_links_rechts)>0:
            for counter,i in enumerate(dictionary_links_rechts.values()):
                bauteile = Bauteil.check_model_representation(bauteildefinition,data_filename,filename,bt_filename,lbd_filename,ifcBridgeName,i,dictionary_tesBauteil,dictionary_feld,dictionary_anfang_ende)
                GlobalId = str(q_main.query_bauteildefinition_hasModelRepresentation(data_filename,bauteildefinition)[counter])
                print("GlobalId: ", end = '')
                print(GlobalId)
        else:
            bauteile = Bauteil.check_model_representation(bauteildefinition,data_filename,filename,bt_filename,lbd_filename,ifcBridgeName,dictionary_links_rechts,dictionary_tesBauteil,dictionary_feld,dictionary_anfang_ende)
            GlobalId = str(q_main.query_bauteildefinition_hasModelRepresentation(data_filename,bauteildefinition)[0])
            print("GlobalId: ", end = '')
            print(GlobalId)

    
    except:
        h = h +1
        print("Error")

print("Errors : " + str(h))
# Out:
# _____________________________________________________
# http://example.org/sibbw7936662#1181817_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# No ifcBridgeName found
# No Bauteil found for Bauteildefinition
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#1276669_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{0: 'Rechts'}
# ifcBridgeName:
# RAILING
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#railing_cecd3ddb-e630-4edf-bad9-db620023ca90
# _____________________________________________________
# http://example.org/sibbw7936662#2800133_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{0: 'Links'}
# ifcBridgeName:
# EDGEBEAM
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#beam_3a64da00-f073-418e-8d87-0d73841c3059
# _____________________________________________________
# http://example.org/sibbw7936662#2809117_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# No ifcBridgeName found
# No Bauteil found for Bauteildefinition
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#2887806_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {'0': 'Control_EndeDesBauwerks'}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# RETAININGWALL
# {'0': 'Control_EndeDesBauwerks'}
# #12300=IfcWall('2zYxyrReP1I8XedMkEgXzQ',#42,'Widerlager A30:Widerlager A30:40722',$,$,#2709,#2703,'40722',.USERDEFINED.)
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#wall_bd8bbf35-6e86-4148-8868-9d6b8eaa1f5a
# _____________________________________________________
# http://example.org/sibbw7936662#3451277_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {'0': 'Control_EndeDesBauwerks'}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# RETAININGWALL
# {'0': 'Control_EndeDesBauwerks'}
# #12300=IfcWall('2zYxyrReP1I8XedMkEgXzQ',#42,'Widerlager A30:Widerlager A30:40722',$,$,#2709,#2703,'40722',.USERDEFINED.)
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#wall_bd8bbf35-6e86-4148-8868-9d6b8eaa1f5a
# _____________________________________________________
# http://example.org/sibbw7936662#3633851_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {'0': 'Control_AnfangDesBauwerks'}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# STAIR
# #12316=IfcStair('3axxe6nunEouLrjAJpmbk1',#42,'Ortbetontreppe:Treppe:160396 Run 1',$,$,#6104,#6581,'160566',$)
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#3777670_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {'0': 'Control_AnfangDesBauwerks'}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# SLAB
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#slab_4f1c5e37-811c-429e-8ae8-e6037f337660
# _____________________________________________________
# http://example.org/sibbw7936662#3847611_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {0: '3. BauteilVonLinks'}
# Feld :{0: '1. Feld'}
# Links/Rechts:{}
# ifcBridgeName:
# GIRDER_SEGMENT
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#beam_3a4cc8ed-6a18-4e8e-b359-3f81d5b776e2
# _____________________________________________________
# http://example.org/sibbw7936662#4342969_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{0: 'Rechts'}
# ifcBridgeName:
# RAILING
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#railing_cecd3ddb-e630-4edf-bad9-db620023ca90
# _____________________________________________________
# http://example.org/sibbw7936662#4508445_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {'0': 'ignore'}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# No ifcBridgeName found
# No Bauteil found for Bauteildefinition
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#4673451_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {0: '1. BauteilVonLinks'}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# No ifcBridgeName found
# No Bauteil found for Bauteildefinition
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#4704780_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{0: 'Links', 1: 'Rechts'}
# ifcBridgeName:
# RAILING
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#railing_cecd3ddb-e630-4edf-bad9-db620023cab2
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#railing_cecd3ddb-e630-4edf-bad9-db620023cab2
# _____________________________________________________
# http://example.org/sibbw7936662#4831229_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{0: 'Rechts'}
# ifcBridgeName:
# No ifcBridgeName found
# No Bauteil found for Bauteildefinition
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#5046824_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{0: 'Links', 1: 'Rechts'}
# ifcBridgeName:
# EDGEBEAM
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#beam_3a64da00-f073-418e-8d87-0d73841c3059
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#beam_bae0fd65-aae8-4a94-97d8-46b63b85dd11
# _____________________________________________________
# http://example.org/sibbw7936662#5281584_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# No ifcBridgeName found
# No Bauteil found for Bauteildefinition
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#6088314_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{0: 'Links', 1: 'Rechts'}
# ifcBridgeName:
# GUARDRAIL
# No Bauteil found for Bauteildefinition
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#6640052_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {'0': 'ignore'}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# SLAB
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#slab_4f1c5e37-811c-429e-8ae8-e6037f337660
# _____________________________________________________
# http://example.org/sibbw7936662#6763612_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {'0': 'Control_AnfangDesBauwerks'}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# RETAININGWALL
# {'0': 'Control_AnfangDesBauwerks'}
# #12298=IfcWall('2qGPtcAsPDyPGkPCgSPvit',#42,'Widerlager A10:Widerlager A10:18057',$,$,#2165,#2159,'18057',.USERDEFINED.)
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#wall_b4419de6-2b66-4df1-942e-64ca9c679b37
# _____________________________________________________
# http://example.org/sibbw7936662#6799929_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {'0': 'Control_AnfangDesBauwerks'}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# SLAB
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#slab_4f1c5e37-811c-429e-8ae8-e6037f337660
# _____________________________________________________
# http://example.org/sibbw7936662#7702465_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {'0': 'Control_AnfangDesBauwerks'}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# SLAB
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#slab_4f1c5e37-811c-429e-8ae8-e6037f337660
# _____________________________________________________
# http://example.org/sibbw7936662#8718212_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {0: '4. BauteilVonLinks'}
# Feld :{0: '1. Feld'}
# Links/Rechts:{}
# ifcBridgeName:
# GIRDER_SEGMENT
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#beam_3a4cc8ed-6a18-4e8e-b359-3f81d5b77410
# _____________________________________________________
# http://example.org/sibbw7936662#8746043_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# No ifcBridgeName found
# No Bauteil found for Bauteildefinition
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#8825206_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {'0': 'Control_AnfangDesBauwerks'}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# RETAININGWALL
# {'0': 'Control_AnfangDesBauwerks'}
# #12298=IfcWall('2qGPtcAsPDyPGkPCgSPvit',#42,'Widerlager A10:Widerlager A10:18057',$,$,#2165,#2159,'18057',.USERDEFINED.)
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#wall_b4419de6-2b66-4df1-942e-64ca9c679b37
# _____________________________________________________
# http://example.org/sibbw7936662#8934595_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {'0': 'ignore'}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# EDGEBEAM
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#9351023_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# GIRDER_SEGMENT
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#9421446_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# No ifcBridgeName found
# No Bauteil found for Bauteildefinition
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#9607498_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{0: 'Links', 1: 'Rechts'}
# ifcBridgeName:
# RAILING
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#railing_cecd3ddb-e630-4edf-bad9-db620023cab2
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#railing_cecd3ddb-e630-4edf-bad9-db620023cab2
# _____________________________________________________
# http://example.org/sibbw7936662#2765576_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# No ifcBridgeName found
# No Bauteil found for Bauteildefinition
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#3303379_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# SLAB
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#slab_4f1c5e37-811c-429e-8ae8-e6037f337660
# _____________________________________________________
# http://example.org/sibbw7936662#8374435_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{}
# ifcBridgeName:
# GIRDER_SEGMENT
# Error
# _____________________________________________________
# http://example.org/sibbw7936662#9579167_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{0: 'Rechts'}
# ifcBridgeName:
# EDGEBEAM
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#beam_bae0fd65-aae8-4a94-97d8-46b63b85dd11
# _____________________________________________________
# http://example.org/sibbw7936662#5137984_BauteilDefinition
# Nicht klassifizierte Ortsangaben: {}
# Ortsangaben Anfang/Ende: {}
# Ortsangaben für Bauteilsuche: {}
# Feld :{}
# Links/Rechts:{0: 'Links', 1: 'Rechts'}
# ifcBridgeName:
# EDGEBEAM
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#beam_3a64da00-f073-418e-8d87-0d73841c3059
# GlobalId: https://asbingowl.org/TwinGenDemo/BW452#beam_bae0fd65-aae8-4a94-97d8-46b63b85dd11
# Errors : 14
