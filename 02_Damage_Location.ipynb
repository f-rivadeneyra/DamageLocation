# %%
import Bauteil,AOI,BCF,Control
import q_main
import ifcopenshell
from ifcopenshell.util.selector import Selector
from ifcopenshell.util import element
selector = Selector()
settings = ifcopenshell.geom.settings()
settings.set(settings.USE_PYTHON_OPENCASCADE, True) 

### Enter data file name (.ttl) ###

data_filename = 'st_2079.ttl'

### Enter model file name (.ifc) ###

filename = "st_2079.ifc"

### Enter model file name converted to LBD-Format (.ttl) ###

lbd_filename = 'st_2079_lbd.ttl'

### The next files will be created 

bt_filename = "control.ifc"
aoi_filename = "damage.ifc"

### Damage location starts here:

AOI.create_aoi_file(data_filename,filename,aoi_filename)

model = ifcopenshell.open(filename)
f = ifcopenshell.open(bt_filename)
g = ifcopenshell.open(aoi_filename)

schadenObjekte_list = q_main.get_schadenObjekte(data_filename)

i = 0

for schadenObjekt in schadenObjekte_list:
    try:
            
        print("__________________________________________________________________________________________________________")    
        schadenquery = q_main.query_schaden_btd(data_filename,schadenObjekt)
        for bauteildefinition in schadenquery:
            print("Schaden: ", end = '')
            print(schadenObjekt)
            print("Bauteildefinition: ", end = '')
            print(bauteildefinition)
            bauteilTyp = q_main.query_bauteildefinition_bauteilTyp(data_filename,bauteildefinition)
            print("Bauteil Typ: ", end = '')
            print(bauteilTyp)

            AOI.bauteildefinition_as_aoi(bauteildefinition,data_filename,schadenObjekt,0,bauteilTyp)
            if "AOI" in schadenquery:
                aoi = q_main.query_aoi(data_filename,str(schadenquery["AOI"]))
                print("AOI: ", end = '')
                print(aoi)
        
            AOI.aoi_main(schadenObjekt,bauteildefinition,data_filename,filename,bt_filename,aoi_filename,lbd_filename)

    except:
        print("Error")
        i = i + 1

print("number of errors : " + str(i))
# Out:
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#2940910_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#2765576_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#4510767_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#5281584_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#7009729_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#9421446_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#9372805_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#2765576_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#1271426_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#8718212_BauteilDefinition
# Bauteil Typ: GIRDER_SEGMENT
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#1926550_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#7702465_BauteilDefinition
# Bauteil Typ: SLAB
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#2063158_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#2809117_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#2098930_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#9351023_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#2674913_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#5137984_BauteilDefinition
# Bauteil Typ: EDGEBEAM
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#2686816_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#6763612_BauteilDefinition
# Bauteil Typ: Widerlager_Wand_Hinten
# New AOI: 1208604_AOI
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#2750690_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#4831229_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#2803116_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#8374435_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#2933965_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#5046824_BauteilDefinition
# Bauteil Typ: EDGEBEAM
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#3531729_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#3451277_BauteilDefinition
# Bauteil Typ: Widerlager_Wand_Vorne
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#3538798_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#9579167_BauteilDefinition
# Bauteil Typ: EDGEBEAM
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#3679216_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#3303379_BauteilDefinition
# Bauteil Typ: SLAB
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#3702732_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#3777670_BauteilDefinition
# Bauteil Typ: SLAB
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#4084380_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#8825206_BauteilDefinition
# Bauteil Typ: Fluegel_Wand_Hinten
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#4125163_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#3303379_BauteilDefinition
# Bauteil Typ: SLAB
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#4790208_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#4508445_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#4790281_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#2887806_BauteilDefinition
# Bauteil Typ: Widerlager_Wand_Vorne
# New AOI: 7165807_AOI
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#4988547_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#4342969_BauteilDefinition
# Bauteil Typ: RAILING
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#5500619_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#6799929_BauteilDefinition
# Bauteil Typ: SLAB
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#5594637_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#9579167_BauteilDefinition
# Bauteil Typ: EDGEBEAM
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#6407987_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#8746043_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#6965339_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#1181817_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#7262061_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#5137984_BauteilDefinition
# Bauteil Typ: EDGEBEAM
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#7546340_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#3847611_BauteilDefinition
# Bauteil Typ: GIRDER_SEGMENT
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#8662694_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#1276669_BauteilDefinition
# Bauteil Typ: RAILING
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#8801152_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#4673451_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#8961047_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#2800133_BauteilDefinition
# Bauteil Typ: EDGEBEAM
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#9029203_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#6088314_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#9558680_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#6640052_BauteilDefinition
# Bauteil Typ: SLAB
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#9797960_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#8374435_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#6572348_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#8934595_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#7424358_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#4704780_BauteilDefinition
# Bauteil Typ: RAILING
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#7769255_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#9607498_BauteilDefinition
# Bauteil Typ: RAILING
# New AOI: 2217766_AOI
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#9238128_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#3633851_BauteilDefinition
# Bauteil Typ: Proxy
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#2660964_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#5137984_BauteilDefinition
# Bauteil Typ: EDGEBEAM
# __________________________________________________________________________________________________________
# Schaden: http://example.org/sibbw7936662#3183006_SchadenObjekt
# Bauteildefinition: http://example.org/sibbw7936662#5137984_BauteilDefinition
# Bauteil Typ: EDGEBEAM
# number of errors : 0
